# %% [markdown]
# # Структура проекта SBER_PROJECT_GRUSHINDA
#
# ```text
# SBER_PROJECT_GRUSHINDA/
# ├── app/                            # Веб-приложение / API слой
# │   ├── templates/                  # HTML-шаблоны для веб-интерфейса
# │   │   └── index.html              # Главная страница приложения
# │   └── api.py                      # Скрипт API
# ├── catboost_info/                  # Автоматические логи обучения CatBoost
# ├── dev/                            # Директория для разработки и анализа данных
# │   ├── catboost_info/              # Логи обучения CatBoost для локальных тестов
# │   ├── data/                       # Исходные датасеты для анализа
# │   │   ├── cat_uniq_data.csv       # Уникальные категории данных
# │   │   ├── ga_hits.csv             # Хит-логи Google Analytics
# │   │   └── ga_sessions.csv         # Сессии Google Analytics
# │   ├── Соответствие action : label (1:m).csv   # Маппинг действий к меткам
# │   ├── Соответствие category : action (1:m).csv # Маппинг категорий к действиям
# │   ├── Соответствие label : action (1:m).csv   # Маппинг меток к действиям
# │   ├── Уникальные значения.csv     # Справочник уникальных значений
# │   └── EDA.ipynb                   # Разведочный анализ данных (Jupyter Notebook)
# ├── models/                         # Модуль машинного обучения и продакшн-моделей
# │   ├── __pycache__/                # Кэш
# │   │   └── my_functions2model.cpython-314.pyc
# │   ├── data/                       # Копия данных или валидационный датасет
# │   │   ├── cat_uniq_data.csv
# │   │   ├── ga_hits.csv
# │   │   └── ga_sessions.csv
# │   ├── model_v1.pkl                # Сериализованная обученная модель CatBoost
# │   ├── model.py                    # Скрипт для обучения модели
# │   └── my_functions2model.py       # Функции предобработки для модели
# ├── .gitignore                      # Исключения
# └── readme.ipynb                    # Документация проекта
# ```

# %% [markdown]
# ## <span style="color: red;">!!! обязательно нужен файл SBER_PROJECT_GRUSHINDA/models/data/cat_uniq_data.csv </span>
# он содержит набор top парметров для категориальных признаков на котрых училась модель!

# %% [markdown]
# Для запуска модели необходимо выполнить 2-а шагга:
#
# 1) Запустить сервер
# 2) Перейти по ссылке "Страница с формой предсказания"

# %% [markdown]
# # Запустить сервер

# %%
# !python3 app/api.py
# Out:
#  * Serving Flask app 'api'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 439-115-108
# ШАГ 1 - gda_drop_col
# ШАГ 2 - gda_set_moda
# ШАГ 3 - gda_set_date_feature
# ШАГ 4 - gda_set_mult
# ШАГ 5 - gda_leave_only_top_val
# ШАГ 6 - fin
# 127.0.0.1 - - [14/May/2026 10:42:24] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2026 10:42:28] "GET /predict HTTP/1.1" 200 -
# ШАГ 1 - gda_drop_col
# ШАГ 2 - gda_set_moda
# ШАГ 3 - gda_set_date_feature
# ШАГ 4 - gda_set_mult
# ШАГ 5 - gda_leave_only_top_val
# ШАГ 6 - fin
# 127.0.0.1 - - [14/May/2026 10:43:07] "POST /predict HTTP/1.1" 200 -

# %% [markdown]
# ## [Тестовая станица сервера](http://localhost:5000/test)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## [Страница с формой предсказания ](http://localhost:5000/predict)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
