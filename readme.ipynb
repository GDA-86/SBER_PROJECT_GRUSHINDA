# %% [markdown]
# # Запустить сервер

# %%
# !python3 app/api.py
# Out:
#  * Serving Flask app 'api'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 439-115-108
# {'session_id': '1', 'client_id': '1', 'visit_date': '2021-11-05', 'visit_time': '08:00:00', 'visit_number': 1, 'utm_source': 'ZpYg2yE3SRE9gZAKgCcA', 'utm_medium': 'banner', 'utm_campaign': 'LEoPHuyFvSTXwSgQKVwB', 'utm_adcontent': 'JNHcZ2gToGlvF933XZNx', 'utm_keyword': ' some_keyword', 'device_category': 'mobile', 'device_os': 'Android', 'device_brand': 'Huawei', 'device_model': '', 'device_screen_resolution': '360x780', 'device_browser': 'Chrome', 'geo_country': 'Russia', 'geo_city': 'Moscow'}
#   session_id client_id  visit_date  ... device_browser  geo_country geo_city
# 0          1         1  2021-11-05  ...         Chrome       Russia   Moscow
#
# [1 rows x 18 columns]
# ...

# %% [markdown]
# ## [Тестовая станица сервера](http://localhost:5000/test)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## [Страница с формой предсказания ](http://localhost:5000/predict)

# %% [markdown]
# ![image.png](attachment:image.png)
